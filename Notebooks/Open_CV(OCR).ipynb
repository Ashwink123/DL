# %%
import cv2

# %%
img = cv2.imread(r'/mnt/c/Users/Ashwin/Documents/Ash/Projects/DL/Data/siberian-husky-sitting_Aleksandr-Abrosimov-Shutterstock.jpg')
print(img.shape)
# Out:
# (540, 810, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)) # converting BGR to RGB for using matplotlib
plt.show()

# %%
plt.imshow(img[:,:,1])

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray, cmap='gray')

# %%
import cv2
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# function to plot n images using subplots
def plot_image(images, captions=None, cmap=None ):
    f, axes = plt.subplots(1, len(images), sharey=True)
    f.set_figwidth(15)
    for ax,image,caption in zip(axes, images, captions):
        ax.imshow(image, cmap)
        ax.set_title(caption)

# %%
# Here, we define some colours
SCALAR_BLACK = (0.0,0.0,0.0)
SCALAR_WHITE = (255.0,255.0,255.0)
SCALAR_YELLOW = (0.0,255.0,255.0)
SCALAR_GREEN = (0.0,255.0,0.0)
SCALAR_RED = (0.0,0.0,255.0)
SCALAR_CYAN = (255.0,255.0,0.0)

# %%
# image
image = np.array([[20,20,20,10,10,10], [20,20,20,10,10,10],[20,20,20,10,10,10],[20,20,20,10,10,10],[20,20,20,10,10,10],[20,20,20,10,10,10]],dtype=np.float32)
plt.imshow(image, cmap= 'gray')

# %%
kernel = np.array([[1,0,-1], [1,0,-1],[1,0,-1]],dtype=np.float64)
kernel
# Out:
# array([[ 1.,  0., -1.],
#        [ 1.,  0., -1.],
#        [ 1.,  0., -1.]])

# %%
plt.imshow(kernel,cmap='gray')

# %%
convolution = cv2.filter2D(image,-1,kernel)
plt.imshow(convolution,cmap='gray')

# %%
### Canny Edge Detector
edge = cv2.Canny(img,300,300)
plot_image([img,edge],cmap='gray',captions=['Husky','Husky Edge'])

# %%
import pytesseract

# %%
import matplotlib as mpl
def plotter(img,cmap=None):
  if cmap == 'gray':
    height,width = img.shape
  else:
    img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    height,width = img.shape

  dpi = mpl.rcParams['figure.dpi']
    # What size does the figure need to be in inches to fit the image?
  figsize = width / float(dpi), height / float(dpi)

    # Create a figure of the right size with one axes that takes up the full figure
  fig = plt.figure(figsize=figsize)

    # Display the image.
  plt.imshow(image, cmap)

# %%
plt.figure(figsize=(20,18))
text_img = cv2.imread('/mnt/c/Users/Ashwin/Documents/Ash/Projects/DL/Data/Book_Page.jpg')
plt.imshow(text_img)

# %%
text = pytesseract.image_to_string(text_img)
print(text)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# of difference equations underlies all of the time-series methods employed in
# apters of this text. It is fair to say that time-series econometrics is concerned with
# non of difference equations containing stochastic components. The traditional
# [time-series analysis was to forecast the time path of a variable. Uncovering the
# gic path of a series improves forecasts since the predictable components of the
# can be extrapolated into the future. The growing interest in economic dynamics
# yen a new emphasis to time-series econometrics. Stochastic difference equations
# , quite naturally, from dynamic economic models. Appropriately estimated equa-
# a be used for the interpretation of economic data and for hypothesis testing.
# S introductory chapter has three aims:
#
# Explain how stochastic difference equations can be used for forecasting,
# and illustrate how such equations can arise from familiar economic models.
# ...

# %%
plt.figure(figsize=(20,18))
grey_text = cv2.cvtColor(text_img,cv2.COLOR_BGR2GRAY)
plt.imshow(grey_text,cmap='gray')
